# %%
from PIL import Image, ImageDraw, ImageFont
import os
import cv2
import numpy as np

# %% [markdown]
# ## Directorys Laden

# %%
# Pfade zu den Bildverzeichnissen
image_filenames_selected = "Vis/SelectedforVis/"
image_path = "Dataset_new/images/"
mask_path = "Dataset_new/masks/"
opencv_path = "results/opencv/"
sd_path = "results/sd/"
lama_path = "results/lama/"

# %%
# Liste der Dateinamen (ohne Verzeichnisse)
image_filenames = [
    "ADE_frame_00000021.jpg",
    "ADE_frame_00000042.jpg",
    "ADE_frame_00000045.jpg",
    "ADE_frame_00000094.jpg",
    "ADE_frame_00000105.jpg",
    "ADE_frame_00000154.jpg",
    "ADE_frame_00000166.jpg",
    "ADE_train_00000003.jpg",
    "ADE_train_00000651.jpg",
    "ADE_train_00000655.jpg",
    "ADE_train_00000658.jpg",
    "ADE_train_00000667.jpg",
    "ADE_train_00001222.jpg",
    "ADE_train_00001489.jpg",
    "ADE_train_00001490.jpg",
    "ADE_train_00001492.jpg",
    "ADE_train_00001494.jpg",
    "ADE_train_00001551.jpg",
    "ADE_train_00001552.jpg",
    "ADE_train_00001554.jpg",
    "ADE_train_00001558.jpg",
    "ADE_train_00001561.jpg",
    "ADE_train_00001607.jpg",
    "ADE_train_00001633.jpg",
    "ADE_train_00001634.jpg",
    "ADE_train_00001639.jpg",
    "ADE_train_00001646.jpg",
    "ADE_train_00001657.jpg",
    "ADE_train_00001707.jpg",
    "ADE_train_00005392.jpg",
    "ADE_train_00009499.jpg",
    "ADE_train_00012229.jpg",
    "ADE_train_00015288.jpg",
    "ADE_train_00022632.jpg",
    "ADE_train_00022636.jpg",
    "ADE_train_00022703.jpg",
    "ADE_train_00024787.jpg",
    "ADE_train_00025023.jpg"
]

# %% [markdown]
# ## Original - Mask - Lama Laden

# %%
# Zielverzeichnis für die kombinierten Bilder
output_dir = "Vis/Lama/combined_images/"
os.makedirs(output_dir, exist_ok=True)

# %%
for filename in image_filenames:
    try:
        # Bilder laden
        original_img = Image.open(os.path.join(image_path, filename))
        mask_img = Image.open(os.path.join(mask_path, filename))
        lama_img = Image.open(os.path.join(lama_path, filename))

        # Alle Bilder auf die gleiche Größe skalieren
        width, height = original_img.size
        mask_img = mask_img.resize((width, height))
        lama_img = lama_img.resize((width, height))
        
        

        # Kombinierte Breite und Höhe berechnen
        combined_width = width * 3
        combined_height = height

        # Neues Bild erstellen
        combined_img = Image.new("RGB", (combined_width, combined_height))

        # Einzelbilder nebeneinander einfügen
        combined_img.paste(original_img, (0, 0))
        combined_img.paste(mask_img, (width, 0))
        combined_img.paste(lama_img, (width * 2, 0))
        
    

        # Kombiniertes Bild speichern
        output_path = os.path.join(output_dir, filename)
        combined_img.save(output_path)

        print(f"Kombiniertes Bild gespeichert: {output_path}")
    except Exception as e:
        print(f"Fehler bei {filename}: {e}")
# Out:
# Kombiniertes Bild gespeichert: Vis/Lama/combined_images/ADE_frame_00000021.jpg
# Kombiniertes Bild gespeichert: Vis/Lama/combined_images/ADE_frame_00000042.jpg
# Kombiniertes Bild gespeichert: Vis/Lama/combined_images/ADE_frame_00000045.jpg
# Kombiniertes Bild gespeichert: Vis/Lama/combined_images/ADE_frame_00000094.jpg
# Kombiniertes Bild gespeichert: Vis/Lama/combined_images/ADE_frame_00000105.jpg
# Kombiniertes Bild gespeichert: Vis/Lama/combined_images/ADE_frame_00000154.jpg
# Kombiniertes Bild gespeichert: Vis/Lama/combined_images/ADE_frame_00000166.jpg
# Kombiniertes Bild gespeichert: Vis/Lama/combined_images/ADE_train_00000003.jpg
# Kombiniertes Bild gespeichert: Vis/Lama/combined_images/ADE_train_00000651.jpg
# Kombiniertes Bild gespeichert: Vis/Lama/combined_images/ADE_train_00000655.jpg
# Kombiniertes Bild gespeichert: Vis/Lama/combined_images/ADE_train_00000658.jpg
# Kombiniertes Bild gespeichert: Vis/Lama/combined_images/ADE_train_00000667.jpg
# Kombiniertes Bild gespeichert: Vis/Lama/combined_images/ADE_train_00001222.jpg
# Kombiniertes Bild gespeichert: Vis/Lama/combined_images/ADE_train_00001489.jpg
# Kombiniertes Bild gespeichert: Vis/Lama/combined_images/ADE_train_00001490.jpg
# Kombiniertes Bild gespeichert: Vis/Lama/combined_images/ADE_train_00001492.jpg
# Kombiniertes Bild gespeichert: Vis/Lama/combined_images/ADE_train_00001494.jpg
# Kombiniertes Bild gespeichert: Vis/Lama/combined_images/ADE_train_00001551.jpg
# Kombiniertes Bild gespeichert: Vis/Lama/combined_images/ADE_train_00001552.jpg
# Kombiniertes Bild gespeichert: Vis/Lama/combined_images/ADE_train_00001554.jpg
# Kombiniertes Bild gespeichert: Vis/Lama/combined_images/ADE_train_00001558.jpg
# Kombiniertes Bild gespeichert: Vis/Lama/combined_images/ADE_train_00001561.jpg
# Kombiniertes Bild gespeichert: Vis/Lama/combined_images/ADE_train_00001607.jpg
# Kombiniertes Bild gespeichert: Vis/Lama/combined_images/ADE_train_00001633.jpg
# Kombiniertes Bild gespeichert: Vis/Lama/combined_images/ADE_train_00001634.jpg
# Kombiniertes Bild gespeichert: Vis/Lama/combined_images/ADE_train_00001639.jpg
# Kombiniertes Bild gespeichert: Vis/Lama/combined_images/ADE_train_00001646.jpg
# Kombiniertes Bild gespeichert: Vis/Lama/combined_images/ADE_train_00001657.jpg
# Kombiniertes Bild gespeichert: Vis/Lama/combined_images/ADE_train_00001707.jpg
# Kombiniertes Bild gespeichert: Vis/Lama/combined_images/ADE_train_00005392.jpg
# Kombiniertes Bild gespeichert: Vis/Lama/combined_images/ADE_train_00009499.jpg
# Kombiniertes Bild gespeichert: Vis/Lama/combined_images/ADE_train_00012229.jpg
# Kombiniertes Bild gespeichert: Vis/Lama/combined_images/ADE_train_00015288.jpg
# Kombiniertes Bild gespeichert: Vis/Lama/combined_images/ADE_train_00022632.jpg
# Kombiniertes Bild gespeichert: Vis/Lama/combined_images/ADE_train_00022636.jpg
# Kombiniertes Bild gespeichert: Vis/Lama/combined_images/ADE_train_00022703.jpg
# Kombiniertes Bild gespeichert: Vis/Lama/combined_images/ADE_train_00024787.jpg
# Kombiniertes Bild gespeichert: Vis/Lama/combined_images/ADE_train_00025023.jpg

# %% [markdown]
# ## Alle Bilder Laden mit Titel

# %%
# Zielverzeichnis für die kombinierten Bilder
output_dir_2 = "Vis/combined_images/"
os.makedirs(output_dir_2, exist_ok=True)

# %%
def ensure_rgb(img_cv):
    """Stellt sicher, dass das Bild im RGB-Format vorliegt."""
    if len(img_cv.shape) == 2:  # Graustufenbild
        img_cv = cv2.cvtColor(img_cv, cv2.COLOR_GRAY2RGB)
    return img_cv

# %%
def add_title(img, text, width, font_size=20):
    """Fügt einen Titel über dem Bild hinzu."""
    # Platz für Titel hinzufügen
    new_height = img.height + font_size + 10  # 10 px Abstand
    new_img = Image.new("RGB", (width, new_height), "white")
    new_img.paste(img, (0, font_size + 10))
    
    # Text zeichnen
    draw = ImageDraw.Draw(new_img)
    try:
        # Standard-Schriftart verwenden
        font = ImageFont.load_default()
    except:
        font = None

    # Textbreite und Höhe berechnen
    if font:
        if hasattr(font, "getbbox"):  # Neuere Pillow-Versionen
            bbox = font.getbbox(text)
            text_width = bbox[2] - bbox[0]
            text_height = bbox[3] - bbox[1]
        else:  # Ältere Pillow-Versionen
            text_width, text_height = font.getsize(text)
    else:
        text_width = len(text) * font_size // 2  # Schätzung für Breite ohne Font
        text_height = font_size  # Schätzung der Höhe

    # Text zentrieren
    text_x = (width - text_width) // 2
    draw.text((text_x, 5), text, fill="black", font=font)
    return new_img

# %%
for filename in image_filenames:
    try:
        # Bilder laden
        original_img = Image.open(os.path.join(image_path, filename))
        mask_img = Image.open(os.path.join(mask_path, filename))
        opencv_img = Image.open(os.path.join(opencv_path, filename))
        sd_img = Image.open(os.path.join(sd_path, filename))
        lama_img = Image.open(os.path.join(lama_path, filename))

        # Alle Bilder auf die gleiche Größe skalieren
        width, height = original_img.size
        mask_img = mask_img.resize((width, height))
        opencv_img = opencv_img.resize((width, height))
        sd_img = sd_img.resize((width, height))
        lama_img = lama_img.resize((width, height))

        # Titel hinzufügen
        original_img = add_title(original_img, "Original Image", width)
        mask_img = add_title(mask_img, "Mask Image", width)
        opencv_img = add_title(opencv_img, "OpenCV Inpainting", width)
        sd_img = add_title(sd_img, "SD Inpainting", width)
        lama_img = add_title(lama_img, "LaMa Inpainting", width)

        # Kombinierte Breite und Höhe berechnen
        combined_width = width * 5  # Für 5 Bilder
        combined_height = original_img.height  # Höhe inkl. Titel

        # Neues Bild erstellen
        combined_img = Image.new("RGB", (combined_width, combined_height), "white")

        # Einzelbilder nebeneinander einfügen
        combined_img.paste(original_img, (0, 0))
        combined_img.paste(mask_img, (width, 0))
        combined_img.paste(opencv_img, (width * 2, 0))
        combined_img.paste(sd_img, (width * 3, 0))
        combined_img.paste(lama_img, (width * 4, 0))

        # Kombiniertes Bild speichern
        output_path = os.path.join(output_dir_2, filename)
        combined_img.save(output_path)

        print(f"Kombiniertes Bild gespeichert: {output_path}")
    except Exception as e:
        print(f"Fehler bei {filename}: {e}")
# Out:
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_frame_00000021.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00011914.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001736.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00022689.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001722.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00022676.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001656.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00015623.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00005418.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00010767.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00003096.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00003082.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00022702.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00021747.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001497.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00016855.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00020471.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_frame_00000154.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00020470.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001496.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00002148.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00022703.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001694.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00003083.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00003097.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00010000.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00010766.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00005419.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00008673.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001657.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001643.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00022663.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00022677.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00025118.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00004840.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001723.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001737.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00020276.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00021168.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00002000.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00012239.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001721.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001735.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001709.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00004842.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00022649.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001641.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001669.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00003081.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001696.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001682.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00003095.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00022701.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00004249.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001494.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00011863.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00020473.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00009977.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00021745.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001495.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00022700.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00003094.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001697.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00003080.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00025047.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00010765.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001668.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001640.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001654.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00024577.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00022648.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001708.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001734.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001720.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001522.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00012214.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001240.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00012228.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001718.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001724.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001730.jpg
# Fehler bei ADE_train_00432.jpg: [Errno 2] No such file or directory: '/Users/luisadosch/Documents/Master/Seminararbeit/MaSeInpaint/Dataset_new/masks/ADE_train_00432.jpg'
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_frame_00000219.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001678.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00005350.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001650.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001644.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00005344.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00024361.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00022710.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00022704.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00005393.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00003084.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001693.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00003090.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00011669.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001334.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_frame_00000153.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001491.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00021740.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001490.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00009972.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_frame_00000152.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001335.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00000003.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00011668.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00003091.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00005392.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001692.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00003085.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001645.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00005345.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001731.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001725.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001719.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_frame_00000026.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00012229.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001733.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001727.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00022698.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00003078.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00005347.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001647.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001653.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00024362.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00022713.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001684.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00003093.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00003087.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001848.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001690.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00020474.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00021742.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001492.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001493.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00020475.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001336.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001691.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001849.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00003086.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00003092.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001685.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00010978.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00024363.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00022706.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001652.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00005346.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001646.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00010763.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00003079.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001726.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00022699.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001732.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00008299.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_frame_00000025.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00011904.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00012216.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00000675.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00000661.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_frame_00000042.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00013812.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00009686.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001755.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001741.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001769.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00002274.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001796.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001635.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00002300.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00010062.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00022985.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00004956.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00022761.jpg
# Fehler bei ADE_train_00000701.jpg: [Errno 2] No such file or directory: '/Users/luisadosch/Documents/Master/Seminararbeit/MaSeInpaint/Dataset_new/masks/ADE_train_00000701.jpg'
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00023133.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00019293.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00019287.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00019286.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00019292.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00024113.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00023640.jpg
# Fehler bei ADE_train_00000700.jpg: [Errno 2] No such file or directory: '/Users/luisadosch/Documents/Master/Seminararbeit/MaSeInpaint/Dataset_new/masks/ADE_train_00000700.jpg'
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00019279.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00022760.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001807.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00002301.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001634.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00005334.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_frame_00000255.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001797.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00002275.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001768.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001740.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001754.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_frame_00000043.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00013813.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00000660.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_frame_00000094.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00012270.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00000674.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00008214.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001554.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00000662.jpg
# Fehler bei ADE_train_00000676.jpg: [Errno 2] No such file or directory: '/Users/luisadosch/Documents/Master/Seminararbeit/MaSeInpaint/Dataset_new/masks/ADE_train_00000676.jpg'
# Fehler bei ADE_train_00000689.jpg: [Errno 2] No such file or directory: '/Users/luisadosch/Documents/Master/Seminararbeit/MaSeInpaint/Dataset_new/masks/ADE_train_00000689.jpg'
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00013811.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_frame_00000041.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001742.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001756.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00002277.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00003169.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00005281.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00002288.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00008799.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001636.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00008809.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00004955.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00022986.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001811.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001805.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00022762.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00016148.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001346.jpg
# Fehler bei ADE_train_00000702.jpg: [Errno 2] No such file or directory: '/Users/luisadosch/Documents/Master/Seminararbeit/MaSeInpaint/Dataset_new/masks/ADE_train_00000702.jpg'
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00019284.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00019290.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00019291.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00019285.jpg
# Fehler bei ADE_train_00000703.jpg: [Errno 2] No such file or directory: '/Users/luisadosch/Documents/Master/Seminararbeit/MaSeInpaint/Dataset_new/masks/ADE_train_00000703.jpg'
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00016149.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00022763.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00022987.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00008808.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00004954.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00006616.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00002302.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001637.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00008798.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00005280.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00002289.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001780.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00002276.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001757.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001743.jpg
# Fehler bei ADE_train_00000688.jpg: [Errno 2] No such file or directory: '/Users/luisadosch/Documents/Master/Seminararbeit/MaSeInpaint/Dataset_new/masks/ADE_train_00000688.jpg'
# Fehler bei ADE_train_00000677.jpg: [Errno 2] No such file or directory: '/Users/luisadosch/Documents/Master/Seminararbeit/MaSeInpaint/Dataset_new/masks/ADE_train_00000677.jpg'
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00000663.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00008217.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00000667.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00000673.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001551.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001237.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00024074.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_frame_00000044.jpg
# Fehler bei ADE_train_00000698.jpg: [Errno 2] No such file or directory: '/Users/luisadosch/Documents/Master/Seminararbeit/MaSeInpaint/Dataset_new/masks/ADE_train_00000698.jpg'
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001592.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00012288.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00002272.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001747.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001753.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001974.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00002299.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00006612.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001633.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00005327.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00006148.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001800.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00004950.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00008818.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00019281.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00019295.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00019294.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00019280.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00006405.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00008819.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00004951.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001801.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00023487.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00005326.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00002461.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00002298.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001752.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001746.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00002273.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00012289.jpg
# Fehler bei ADE_train_00000699.jpg: [Errno 2] No such file or directory: '/Users/luisadosch/Documents/Master/Seminararbeit/MaSeInpaint/Dataset_new/masks/ADE_train_00000699.jpg'
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_frame_00000045.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001550.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001222.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00000672.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00000666.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00000670.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00000664.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00012248.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001552.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00000658.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00020588.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001591.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001778.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00002271.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001750.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001744.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00007484.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001787.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00002463.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00005324.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00005330.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001803.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00022764.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00022758.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00025023.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00004953.jpg
# Fehler bei ADE_train_00000704.jpg: [Errno 2] No such file or directory: '/Users/luisadosch/Documents/Master/Seminararbeit/MaSeInpaint/Dataset_new/masks/ADE_train_00000704.jpg'
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00019296.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00019282.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00023137.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00019283.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00019297.jpg
# Fehler bei ADE_train_00000705.jpg: [Errno 2] No such file or directory: '/Users/luisadosch/Documents/Master/Seminararbeit/MaSeInpaint/Dataset_new/masks/ADE_train_00000705.jpg'
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00004952.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00022759.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001802.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00022765.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00005331.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00002462.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001786.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001792.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001745.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001751.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_frame_00000293.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00002270.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001779.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00024076.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00000659.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00000665.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00012275.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00000671.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00000668.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001562.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00012250.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00000654.jpg
# Fehler bei ADE_train_00000697.jpg: [Errno 2] No such file or directory: '/Users/luisadosch/Documents/Master/Seminararbeit/MaSeInpaint/Dataset_new/masks/ADE_train_00000697.jpg'
# Fehler bei ADE_train_00000683.jpg: [Errno 2] No such file or directory: '/Users/luisadosch/Documents/Master/Seminararbeit/MaSeInpaint/Dataset_new/masks/ADE_train_00000683.jpg'
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001774.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001760.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00002269.jpg
# Fehler bei ADE_train_00001748.jpg: [Errno 2] No such file or directory: '/Users/luisadosch/Documents/Master/Seminararbeit/MaSeInpaint/Dataset_new/masks/ADE_train_00001748.jpg'
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001984.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00009499.jpg
# Fehler bei ADE_train_00022634.jpg: [Errno 2] No such file or directory: '/Users/luisadosch/Documents/Master/Seminararbeit/MaSeInpaint/Dataset_new/masks/ADE_train_00022634.jpg'
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00002282.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00002296.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00005328.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00008803.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00008817.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00008816.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00022999.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00008802.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00005329.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00002297.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00022635.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00002283.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001749.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00002268.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001761.jpg
# Fehler bei ADE_train_00000682.jpg: [Errno 2] No such file or directory: '/Users/luisadosch/Documents/Master/Seminararbeit/MaSeInpaint/Dataset_new/masks/ADE_train_00000682.jpg'
# Fehler bei ADE_train_00000696.jpg: [Errno 2] No such file or directory: '/Users/luisadosch/Documents/Master/Seminararbeit/MaSeInpaint/Dataset_new/masks/ADE_train_00000696.jpg'
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00023926.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00000655.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00000669.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001561.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00012247.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00023924.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00012253.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00000657.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00024078.jpg
# Fehler bei ADE_train_00000680.jpg: [Errno 2] No such file or directory: '/Users/luisadosch/Documents/Master/Seminararbeit/MaSeInpaint/Dataset_new/masks/ADE_train_00000680.jpg'
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00020236.jpg
# Fehler bei ADE_train_00000694.jpg: [Errno 2] No such file or directory: '/Users/luisadosch/Documents/Master/Seminararbeit/MaSeInpaint/Dataset_new/masks/ADE_train_00000694.jpg'
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001763.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00015702.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001777.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00002295.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00002281.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001788.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00010068.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00006150.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00008814.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00004948.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00008800.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00019299.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00019298.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00019501.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00006409.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00008801.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00008815.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00004949.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00002280.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00022636.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00002294.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001776.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00003161.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001762.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_frame_00000061.jpg
# Fehler bei ADE_train_00000695.jpg: [Errno 2] No such file or directory: '/Users/luisadosch/Documents/Master/Seminararbeit/MaSeInpaint/Dataset_new/masks/ADE_train_00000695.jpg'
# Fehler bei ADE_train_00000681.jpg: [Errno 2] No such file or directory: '/Users/luisadosch/Documents/Master/Seminararbeit/MaSeInpaint/Dataset_new/masks/ADE_train_00000681.jpg'
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00000656.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00012246.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00023925.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001560.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001558.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00000652.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001564.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001570.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00020233.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00015288.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_frame_00000071.jpg
# Fehler bei ADE_train_00000685.jpg: [Errno 2] No such file or directory: '/Users/luisadosch/Documents/Master/Seminararbeit/MaSeInpaint/Dataset_new/masks/ADE_train_00000685.jpg'
# Fehler bei ADE_train_00000691.jpg: [Errno 2] No such file or directory: '/Users/luisadosch/Documents/Master/Seminararbeit/MaSeInpaint/Dataset_new/masks/ADE_train_00000691.jpg'
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00013809.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001766.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001772.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001799.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00002290.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00022632.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00002284.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00020192.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00008811.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00008805.jpg
# Fehler bei ADE_train_00016150.jpg: [Errno 2] No such file or directory: '/Users/luisadosch/Documents/Master/Seminararbeit/MaSeInpaint/Dataset_new/masks/ADE_train_00016150.jpg'
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_frame_00000105.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00019288.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00019289.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00008804.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00008810.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001607.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00002285.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00002291.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001798.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001773.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_frame_00000299.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001767.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00013808.jpg
# Fehler bei ADE_train_00000690.jpg: [Errno 2] No such file or directory: '/Users/luisadosch/Documents/Master/Seminararbeit/MaSeInpaint/Dataset_new/masks/ADE_train_00000690.jpg'
# Fehler bei ADE_train_00000684.jpg: [Errno 2] No such file or directory: '/Users/luisadosch/Documents/Master/Seminararbeit/MaSeInpaint/Dataset_new/masks/ADE_train_00000684.jpg'
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001571.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001565.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00000653.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00012243.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001559.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00019300.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00000651.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00012241.jpg
# Fehler bei ADE_train_00000679.jpg: [Errno 2] No such file or directory: '/Users/luisadosch/Documents/Master/Seminararbeit/MaSeInpaint/Dataset_new/masks/ADE_train_00000679.jpg'
# Fehler bei ADE_train_00000692.jpg: [Errno 2] No such file or directory: '/Users/luisadosch/Documents/Master/Seminararbeit/MaSeInpaint/Dataset_new/masks/ADE_train_00000692.jpg'
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_frame_00000066.jpg
# Fehler bei ADE_train_00000686.jpg: [Errno 2] No such file or directory: '/Users/luisadosch/Documents/Master/Seminararbeit/MaSeInpaint/Dataset_new/masks/ADE_train_00000686.jpg'
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001995.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001759.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00002278.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001765.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00002287.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00002293.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001639.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001822.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00008806.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00008812.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00016147.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00008813.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00008807.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001638.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00005338.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00002292.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00002286.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001764.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001770.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00002279.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001758.jpg
# Fehler bei ADE_train_00000687.jpg: [Errno 2] No such file or directory: '/Users/luisadosch/Documents/Master/Seminararbeit/MaSeInpaint/Dataset_new/masks/ADE_train_00000687.jpg'
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00014180.jpg
# Fehler bei ADE_train_00000693.jpg: [Errno 2] No such file or directory: '/Users/luisadosch/Documents/Master/Seminararbeit/MaSeInpaint/Dataset_new/masks/ADE_train_00000693.jpg'
# Fehler bei ADE_train_00000678.jpg: [Errno 2] No such file or directory: '/Users/luisadosch/Documents/Master/Seminararbeit/MaSeInpaint/Dataset_new/masks/ADE_train_00000678.jpg'
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001501.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00012233.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001717.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00003114.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001703.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00022694.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00022680.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001663.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001677.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00019004.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00000555.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00012186.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001850.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001688.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00011666.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00009997.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00002140.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00020444.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00002141.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00011667.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001689.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001851.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00012187.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00002343.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00019005.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00022681.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00022695.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001702.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001716.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_frame_00000015.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00012226.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00012232.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00016054.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001500.jpg
# Fehler bei ADE_train_00001502.jpg: [Errno 2] No such file or directory: '/Users/luisadosch/Documents/Master/Seminararbeit/MaSeInpaint/Dataset_new/masks/ADE_train_00001502.jpg'
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00012218.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00012224.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00012230.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00020241.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00000191.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001700.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001714.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00022683.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00022697.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001728.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00003077.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001648.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00005348.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00022708.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001853.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00012185.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00003088.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00011665.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00011671.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00002143.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001489.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00002142.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00011670.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00009995.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00011664.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00003089.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00012184.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001852.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00010977.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00019006.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001649.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00005349.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001661.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00020863.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001729.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00022682.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001715.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001701.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_frame_00000016.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00012219.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001503.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00012221.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00024787.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00020244.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00022686.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001739.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00022692.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001705.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001711.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00022679.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00002350.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001659.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00003066.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00005417.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001671.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001665.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00003099.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00000584.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00002146.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00004251.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00005167.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_frame_00000166.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00022527.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001498.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001499.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00009990.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00005172.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00002147.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00003098.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001664.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001670.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00005416.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001658.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00002351.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00002345.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00022678.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001710.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001704.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00022693.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00022687.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001738.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00020279.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_frame_00000007.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00012234.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00012220.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00012236.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00002031.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001504.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_frame_00000005.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00020247.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00022691.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00022685.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001712.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001706.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00025115.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001666.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00005414.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001672.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001699.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00004252.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00002145.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00009992.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00011663.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00020469.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00011662.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00004253.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00002144.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00004247.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00022727.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001698.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00005415.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001667.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00020078.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001707.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00003104.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00001713.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00022684.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00014336.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00022690.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images/ADE_train_00012223.jpg

# %% [markdown]
# ## Alle Bilder Laden ohne Titel

# %%
# Zielverzeichnis für die kombinierten Bilder
output_dir_3= "Vis/combined_images_without_titel/"
os.makedirs(output_dir_3, exist_ok=True)

# %%
for filename in image_filenames:
    try:
        # Bilder laden
        original_img = Image.open(os.path.join(image_path, filename))
        mask_img = Image.open(os.path.join(mask_path, filename))
        opencv_img = Image.open(os.path.join(opencv_path, filename))
        sd_img = Image.open(os.path.join(sd_path, filename))
        lama_img = Image.open(os.path.join(lama_path, filename))

        # Alle Bilder auf die gleiche Größe skalieren
        width, height = original_img.size
        mask_img = mask_img.resize((width, height))
        opencv_img = opencv_img.resize((width, height))
        sd_img = sd_img.resize((width, height))
        lama_img = lama_img.resize((width, height))

        # Kombinierte Breite und Höhe berechnen
        combined_width = width * 5  # Für 5 Bilder
        combined_height = original_img.height  # Höhe inkl. Titel

        # Neues Bild erstellen
        combined_img = Image.new("RGB", (combined_width, combined_height), "white")

        # Einzelbilder nebeneinander einfügen
        combined_img.paste(original_img, (0, 0))
        combined_img.paste(mask_img, (width, 0))
        combined_img.paste(opencv_img, (width * 2, 0))
        combined_img.paste(sd_img, (width * 3, 0))
        combined_img.paste(lama_img, (width * 4, 0))

        # Kombiniertes Bild speichern
        output_path3 = os.path.join(output_dir_3, filename)
        combined_img.save(output_path3)

        print(f"Kombiniertes Bild gespeichert: {output_path3}")
    except Exception as e:
        print(f"Fehler bei {filename}: {e}")
# Out:
# Kombiniertes Bild gespeichert: Vis/combined_images_without_titel/ADE_frame_00000021.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images_without_titel/ADE_frame_00000042.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images_without_titel/ADE_frame_00000045.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images_without_titel/ADE_frame_00000094.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images_without_titel/ADE_frame_00000105.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images_without_titel/ADE_frame_00000154.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images_without_titel/ADE_frame_00000166.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images_without_titel/ADE_train_00000003.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images_without_titel/ADE_train_00000651.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images_without_titel/ADE_train_00000655.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images_without_titel/ADE_train_00000658.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images_without_titel/ADE_train_00000667.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images_without_titel/ADE_train_00001222.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images_without_titel/ADE_train_00001489.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images_without_titel/ADE_train_00001490.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images_without_titel/ADE_train_00001492.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images_without_titel/ADE_train_00001494.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images_without_titel/ADE_train_00001551.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images_without_titel/ADE_train_00001552.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images_without_titel/ADE_train_00001554.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images_without_titel/ADE_train_00001558.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images_without_titel/ADE_train_00001561.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images_without_titel/ADE_train_00001607.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images_without_titel/ADE_train_00001633.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images_without_titel/ADE_train_00001634.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images_without_titel/ADE_train_00001639.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images_without_titel/ADE_train_00001646.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images_without_titel/ADE_train_00001657.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images_without_titel/ADE_train_00001707.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images_without_titel/ADE_train_00005392.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images_without_titel/ADE_train_00009499.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images_without_titel/ADE_train_00012229.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images_without_titel/ADE_train_00015288.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images_without_titel/ADE_train_00022632.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images_without_titel/ADE_train_00022636.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images_without_titel/ADE_train_00022703.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images_without_titel/ADE_train_00024787.jpg
# Kombiniertes Bild gespeichert: Vis/combined_images_without_titel/ADE_train_00025023.jpg

# %% [markdown]
# ## Collagen ohne Titel

# %%
# Pfad zu den Bildern
input_dir1 = "Vis/SelectedforVis/"
output_path1 = "Vis/Collage/combined_vertical_image.jpg"  # Ausgabe-Datei

input_dir2 = "Vis/selected_2/"
output_path2 = "Vis/Collage/selected2.jpg"  # Ausgabe-Datei

input_dir3 = "Vis/selected_3/"
output_path3 = "Vis/Collage/selected3.jpg"  # Ausgabe-Datei

# %%
from PIL import Image
import os

def create_collage(input_dir, output_path):
    # Alle Bilddateien aus dem Verzeichnis abrufen
    image_filenames = [f for f in os.listdir(input_dir) if f.endswith(('.png', '.jpg', '.jpeg'))]

    # Sortiere die Bilder für Konsistenz (optional)
    image_filenames.sort()

    # Liste, um geöffnete Bilder zu speichern
    images = []

    # Alle Bilder laden und auf gleiche Größe skalieren
    for filename in image_filenames:
        img_path = os.path.join(input_dir, filename)
        try:
            img = Image.open(img_path)

            # Hier skalieren wir jedes Bild auf die Größe des größten Bildes
            if images:
                max_width = max((img.width for img in images), default=img.width)
                max_height = max((img.height for img in images), default=img.height)
            else:
                max_width, max_height = img.width, img.height

            img = img.resize((max_width, max_height))  # Skalieren auf die Größe des größten Bildes
            images.append(img)
        except Exception as e:
            print(f"Fehler beim Laden von {filename}: {e}")

    # Überprüfen, ob Bilder geladen wurden
    if not images:
        print("Keine gültigen Bilder gefunden!")
    else:
        # Breite und Höhe des kombinierten Bildes berechnen
        total_width = max(img.width for img in images)
        total_height = sum(img.height for img in images)

        # Neues Bild erstellen
        combined_img = Image.new("RGB", (total_width, total_height), "white")

        # Bilder untereinander anordnen
        y_offset = 0
        for img in images:
            combined_img.paste(img, (0, y_offset))
            y_offset += img.height

        # Kombiniertes Bild speichern
        combined_img.save(output_path)
        print(f"Kombiniertes Bild gespeichert unter: {output_path}")

# Definiere die Verzeichnisse und Ausgabepfade für alle 3 Collagen
collage_info = [
    ("Vis/SelectedforVis/", "Vis/Collage/combined_vertical_image_without.jpg"),
    ("Vis/selected_2/", "Vis/Collage/selected2_without.jpg"),
    ("Vis/selected_3/", "Vis/Collage/selected3_without.jpg")
]

# Erstelle für jedes Set von Bildern eine Collage
for input_dir, output_path in collage_info:
    create_collage(input_dir, output_path)
# Out:
# Kombiniertes Bild gespeichert unter: Vis/Collage/combined_vertical_image_withtitle.jpg
# Kombiniertes Bild gespeichert unter: Vis/Collage/selected2_withtitle.jpg
# Kombiniertes Bild gespeichert unter: Vis/Collage/selected3_withtitle.jpg
